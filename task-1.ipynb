# %%
''' Do not change this cell '''
#Functions

def check_gpu():
  if tf.test.gpu_device_name() != '':
    print("GPU sucessfully connected")
  else: print("PLease connect GPU")

# %% [markdown]
# # **#Task 1**#

# %%
#import all the required packages and  libraries for FineTuning LLM

# %%
#Setup and check a gpu connection.

# %%
''' Do not change this cell '''
check_gpu()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 ''' Do not change this cell '''
# ----> 2 check_gpu()
#
# Cell In[2], line 5, in check_gpu()
#       4 def check_gpu():
# ----> 5   if tf.test.gpu_device_name() != '':
#       6     print("GPU sucessfully connected")
#       7   else: print("PLease connect GPU")
#
# NameError: name 'tf' is not defined

# %% [markdown]
# Check the dataset
#
# https://huggingface.co/datasets/jizzu/llama2_indian_law_v2
